# %% [markdown]
# Cerated by Jeana
#
# Modified by Simon

# %%
from google.colab import drive
drive.mount('/content/drive')


# Note: for this line to work, you have to create a shortcut to the CS 3300
# folder in your drive. idk if there is a better workaround
# %cd "/content/drive/MyDrive/INFO 3300"

# Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
from datetime import datetime
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1fWoSbZ4jYziYN4tjISHvtbUrJlsimHku/INFO 3300

# %%
# Load csv files
loc_df = pd.read_csv("crash_data/2M Location Collisions.csv")
# Out:
# <ipython-input-4-879ba581860e>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   loc_df = pd.read_csv("crash_data/2M Location Collisions.csv")

# %%
loc_df = loc_df.drop((['LOCATION', 'CRASH TIME', 'BOROUGH', 'ZIP CODE','ON STREET NAME', 'CROSS STREET NAME', 'OFF STREET NAME', 'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED','NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED','NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1','CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3','CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5','COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2','VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5']), axis=1)

# %%
loc_df
# Out:
#          CRASH DATE   LATITUDE  LONGITUDE
# 0        09/11/2021        NaN        NaN
# 1        03/26/2022        NaN        NaN
# 2        06/29/2022        NaN        NaN
# 3        09/11/2021  40.667202 -73.866500
# 4        12/14/2021  40.683304 -73.917274
# ...             ...        ...        ...
# 2120513  08/06/2024        NaN        NaN
# 2120514  08/05/2024        NaN        NaN
# 2120515  07/29/2024  40.723442 -73.938990
# 2120516  08/02/2024        NaN        NaN
# 2120517  08/06/2024        NaN        NaN
#
# [2120518 rows x 3 columns]

# %%
loc_df = loc_df.dropna(axis=0)
loc_df.loc[:, 'CRASH DATE'] = pd.to_datetime(loc_df['CRASH DATE'], format='%m/%d/%Y')
loc_df
# Out:
#         CRASH DATE   LATITUDE  LONGITUDE
# 3       2021-09-11  40.667202 -73.866500
# 4       2021-12-14  40.683304 -73.917274
# 6       2021-12-14  40.709183 -73.956825
# 7       2021-12-14  40.868160 -73.831480
# 8       2021-12-14  40.671720 -73.897100
# ...            ...        ...        ...
# 2120498 2024-08-06  40.751080 -73.749150
# 2120501 2024-08-04  40.610508 -74.095760
# 2120507 2024-08-06  40.664960 -73.822260
# 2120512 2024-08-06   0.000000   0.000000
# 2120515 2024-07-29  40.723442 -73.938990
#
# [1872698 rows x 3 columns]

# %%
loc_df = loc_df[(loc_df['LATITUDE'] != 0)]
loc_df
# Out:
#         CRASH DATE   LATITUDE  LONGITUDE
# 3       2021-09-11  40.667202 -73.866500
# 4       2021-12-14  40.683304 -73.917274
# 6       2021-12-14  40.709183 -73.956825
# 7       2021-12-14  40.868160 -73.831480
# 8       2021-12-14  40.671720 -73.897100
# ...            ...        ...        ...
# 2120494 2024-08-06  40.747380 -73.761710
# 2120498 2024-08-06  40.751080 -73.749150
# 2120501 2024-08-04  40.610508 -74.095760
# 2120507 2024-08-06  40.664960 -73.822260
# 2120515 2024-07-29  40.723442 -73.938990
#
# [1867963 rows x 3 columns]

# %%
loc_df = loc_df[(loc_df['LONGITUDE'] != 0)]
loc_df
# Out:
#         CRASH DATE   LATITUDE  LONGITUDE
# 3       2021-09-11  40.667202 -73.866500
# 4       2021-12-14  40.683304 -73.917274
# 6       2021-12-14  40.709183 -73.956825
# 7       2021-12-14  40.868160 -73.831480
# 8       2021-12-14  40.671720 -73.897100
# ...            ...        ...        ...
# 2120494 2024-08-06  40.747380 -73.761710
# 2120498 2024-08-06  40.751080 -73.749150
# 2120501 2024-08-04  40.610508 -74.095760
# 2120507 2024-08-06  40.664960 -73.822260
# 2120515 2024-07-29  40.723442 -73.938990
#
# [1867963 rows x 3 columns]

# %%
max([x.year for x in loc_df['CRASH DATE']])
# Out:
# 2024

# %%
# filter to last 5 years
loc_df = loc_df[(loc_df['CRASH DATE'].dt.year >= 2019) & (loc_df['CRASH DATE'].dt.year <= 2024)]

# %%
min([x.year for x in loc_df['CRASH DATE']])
# Out:
# 2019

# %%
loc_df.to_csv('crash_data/lineChart.csv')

# %%
monthly_counts = loc_df.groupby([loc_df['CRASH DATE'].dt.year.rename('Year'), loc_df['CRASH DATE'].dt.month.rename('Month')]).size().reset_index(name='Counts')
monthly_counts
# Out:
#     Year  Month  Counts
# 0   2019      1   15539
# 1   2019      2   14761
# 2   2019      3   16324
# 3   2019      4   15385
# 4   2019      5   17937
# ..   ...    ...     ...
# 64  2024      5    7584
# 65  2024      6    7297
# 66  2024      7    5093
# 67  2024      8     630
# 68  2024      9     798
#
# [69 rows x 3 columns]

# %%
monthly_counts['Date'] = pd.to_datetime(monthly_counts['Month'].astype(str) + '-01-' + monthly_counts['Year'].astype(str), format='%m-%d-%Y')
monthly_counts
# Out:
#     Year  Month  Counts       Date
# 0   2019      1   15539 2019-01-01
# 1   2019      2   14761 2019-02-01
# 2   2019      3   16324 2019-03-01
# 3   2019      4   15385 2019-04-01
# 4   2019      5   17937 2019-05-01
# ..   ...    ...     ...        ...
# 64  2024      5    7584 2024-05-01
# 65  2024      6    7297 2024-06-01
# 66  2024      7    5093 2024-07-01
# 67  2024      8     630 2024-08-01
# 68  2024      9     798 2024-09-01
#
# [69 rows x 4 columns]

# %%
monthly_counts.to_csv('crash_data/Crash_Monthly_Count.csv')
