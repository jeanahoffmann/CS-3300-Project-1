# %%
from google.colab import drive
drive.mount('/content/drive')


# Note: for this line to work, you have to create a shortcut to the CS 3300
# folder in your drive. idk if there is a better workaround
# %cd "/content/drive/MyDrive/INFO 3300"

# Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1fWoSbZ4jYziYN4tjISHvtbUrJlsimHku/INFO 3300

# %%
# Load csv files
loc_df = pd.read_csv("crash_data/2M Location Collisions.csv")
# Out:
# <ipython-input-2-879ba581860e>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   loc_df = pd.read_csv("crash_data/2M Location Collisions.csv")

# %%
loc_df = loc_df.drop((['LOCATION', 'CRASH TIME', 'BOROUGH', 'ZIP CODE','ON STREET NAME', 'CROSS STREET NAME', 'OFF STREET NAME', 'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED','NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED','NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1','CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3','CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5','COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2','VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5']), axis=1)

# %%
loc_df
# Out:
#          CRASH DATE   LATITUDE  LONGITUDE
# 0        09/11/2021        NaN        NaN
# 1        03/26/2022        NaN        NaN
# 2        06/29/2022        NaN        NaN
# 3        09/11/2021  40.667202 -73.866500
# 4        12/14/2021  40.683304 -73.917274
# ...             ...        ...        ...
# 2120513  08/06/2024        NaN        NaN
# 2120514  08/05/2024        NaN        NaN
# 2120515  07/29/2024  40.723442 -73.938990
# 2120516  08/02/2024        NaN        NaN
# 2120517  08/06/2024        NaN        NaN
#
# [2120518 rows x 3 columns]

# %%
loc_df = loc_df.dropna(axis=0)
loc_df
# Out:
#          CRASH DATE   LATITUDE  LONGITUDE
# 3        09/11/2021  40.667202 -73.866500
# 4        12/14/2021  40.683304 -73.917274
# 6        12/14/2021  40.709183 -73.956825
# 7        12/14/2021  40.868160 -73.831480
# 8        12/14/2021  40.671720 -73.897100
# ...             ...        ...        ...
# 2120498  08/06/2024  40.751080 -73.749150
# 2120501  08/04/2024  40.610508 -74.095760
# 2120507  08/06/2024  40.664960 -73.822260
# 2120512  08/06/2024   0.000000   0.000000
# 2120515  07/29/2024  40.723442 -73.938990
#
# [1872698 rows x 3 columns]

# %%
loc_df = loc_df[(loc_df['LATITUDE'] != 0)]
loc_df
# Out:
#          CRASH DATE   LATITUDE  LONGITUDE
# 3        09/11/2021  40.667202 -73.866500
# 4        12/14/2021  40.683304 -73.917274
# 6        12/14/2021  40.709183 -73.956825
# 7        12/14/2021  40.868160 -73.831480
# 8        12/14/2021  40.671720 -73.897100
# ...             ...        ...        ...
# 2120494  08/06/2024  40.747380 -73.761710
# 2120498  08/06/2024  40.751080 -73.749150
# 2120501  08/04/2024  40.610508 -74.095760
# 2120507  08/06/2024  40.664960 -73.822260
# 2120515  07/29/2024  40.723442 -73.938990
#
# [1867963 rows x 3 columns]

# %%
loc_df = loc_df[(loc_df['LONGITUDE'] != 0)]
loc_df
# Out:
#          CRASH DATE   LATITUDE  LONGITUDE
# 3        09/11/2021  40.667202 -73.866500
# 4        12/14/2021  40.683304 -73.917274
# 6        12/14/2021  40.709183 -73.956825
# 7        12/14/2021  40.868160 -73.831480
# 8        12/14/2021  40.671720 -73.897100
# ...             ...        ...        ...
# 2120494  08/06/2024  40.747380 -73.761710
# 2120498  08/06/2024  40.751080 -73.749150
# 2120501  08/04/2024  40.610508 -74.095760
# 2120507  08/06/2024  40.664960 -73.822260
# 2120515  07/29/2024  40.723442 -73.938990
#
# [1867963 rows x 3 columns]

# %%
max([int(x[-4:]) for x in loc_df['CRASH DATE']])
# Out:
# 2024

# %%
# filter to last 5 years
array = [(int(x[-4:]) > 2019) for x in loc_df['CRASH DATE']]
loc_df = loc_df[array]

# %%
min([int(x[-4:]) for x in loc_df['CRASH DATE']])
# Out:
# 2020

# %%
loc_df
# Out:
#          CRASH DATE   LATITUDE  LONGITUDE
# 3        09/11/2021  40.667202 -73.866500
# 4        12/14/2021  40.683304 -73.917274
# 6        12/14/2021  40.709183 -73.956825
# 7        12/14/2021  40.868160 -73.831480
# 8        12/14/2021  40.671720 -73.897100
# ...             ...        ...        ...
# 2120494  08/06/2024  40.747380 -73.761710
# 2120498  08/06/2024  40.751080 -73.749150
# 2120501  08/04/2024  40.610508 -74.095760
# 2120507  08/06/2024  40.664960 -73.822260
# 2120515  07/29/2024  40.723442 -73.938990
#
# [435696 rows x 3 columns]

# %%
loc_df.to_csv('crash_data/920heatmap.csv')

# %%
loc_df = pd.read_csv('crash_data/heatmap.csv').drop(['Unnamed: 0'], axis=1)

# %%
# create latitude and longitude squares of d x d degrees, tally up number of crashes per square
latitudes = []
longitudes = []
for i in range(len(loc_df)):
  latitudes.append(round(loc_df['LATITUDE'].iloc[i], 2)) # change decimal places to get smaller or larger sqaures
  longitudes.append(round(loc_df['LONGITUDE'].iloc[i], 2))

# crashes = []
# for i in range(len(loc_df)):
#   crash_count = len(
#       loc_df[(loc_df["LATITUDE"]==loc_df["LATITUDE"].iloc[i]) &
#           (loc_df["LONGITUDE"]==loc_df["LONGITUDE"].iloc[i])])
#   crashes.append(crash_count)

loc_df['LATITUDE'] = latitudes
loc_df['LONGITUDE'] = longitudes
# loc_df['CRASHES'] = crashes
# Out:
# <ipython-input-10-6d6c90935085>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loc_df['LATITUDE'] = latitudes
# <ipython-input-10-6d6c90935085>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loc_df['LONGITUDE'] = longitudes

# %%
loc_df = loc_df.groupby(['LATITUDE', 'LONGITUDE'],as_index=False).size()

# %%
# Remove duplicates -- only have unique longitude and latitude pairs w/ the counts.
loc_df.drop_duplicates(subset = ['LATITUDE', 'LONGITUDE'])
# Out:
#      LATITUDE  LONGITUDE  size
# 0       40.50     -74.25    14
# 1       40.50     -74.24    27
# 2       40.50     -74.23     2
# 3       40.51     -74.25   118
# 4       40.51     -74.24    94
# ..        ...        ...   ...
# 916     40.91     -73.90   231
# 917     40.91     -73.89     4
# 918     40.91     -73.85   102
# 919     40.93     -73.90     1
# 920     41.40     -74.33     1
#
# [921 rows x 3 columns]

# %%
loc_df = loc_df.drop(['size'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-367caa5eaaa1> in <cell line: 1>()
# ----> 1 loc_df = loc_df.drop(['size'], axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
loc_df["CRASHES"] = loc_df['size']
loc_df = loc_df.drop(['size'], axis=1)
# Out:
#      LATITUDE  LONGITUDE  CRASHES
# 0       40.50     -74.25       14
# 1       40.50     -74.24       27
# 2       40.50     -74.23        2
# 3       40.51     -74.25      118
# 4       40.51     -74.24       94
# ..        ...        ...      ...
# 916     40.91     -73.90      231
# 917     40.91     -73.89        4
# 918     40.91     -73.85      102
# 919     40.93     -73.90        1
# 920     41.40     -74.33        1
#
# [921 rows x 3 columns]

# %%
loc_df.drop(920)
# Out:
#      LATITUDE  LONGITUDE  size  CRASHES
# 0       40.50     -74.25    14       14
# 1       40.50     -74.24    27       27
# 2       40.50     -74.23     2        2
# 3       40.51     -74.25   118      118
# 4       40.51     -74.24    94       94
# ..        ...        ...   ...      ...
# 915     40.91     -73.91    26       26
# 916     40.91     -73.90   231      231
# 917     40.91     -73.89     4        4
# 918     40.91     -73.85   102      102
# 919     40.93     -73.90     1        1
#
# [920 rows x 4 columns]

# %%
import math
log_crashes = []
for i in range(len(loc_df)):
  log_crashes.append(math.log(loc_df['CRASHES'].iloc[i]))

loc_df['LOG_CRASHES'] = log_crashes

# %%
loc_df= loc_df.drop(['size'], axis=1)

# %%
loc_df.to_csv('crash_data/heatmap.csv')

# %%
# save dataframe to a new .csv file and put this on github
